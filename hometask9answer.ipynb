# %%
import pandas as pd
df=pd.read_csv("telecom_churn.csv")
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    OH             107        415                 No             Yes
# 1    NJ             137        415                 No              No
# 2    OH              84        408                Yes              No
# 3    OK              75        415                Yes              No
# 4    AL             118        510                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                      0              223.4               98
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             27.47              195.5              103             16.62
# ...

# %%
df.describe(include="all")
df.shape
# Out:
# (3332, 20)

# %%
column_name=df.columns
for i in column_name:
    print(i)
len(column_name)
# Out:
# State
# Account length
# Area code
# International plan
# Voice mail plan
# Number vmail messages
# Total day minutes
# Total day calls
# Total day charge
# Total eve minutes
# Total eve calls
# Total eve charge
# Total night minutes
# Total night calls
# Total night charge
# Total intl minutes
# Total intl calls
# Total intl charge
# Customer service calls
# Churn
# 20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3332 entries, 0 to 3331
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3332 non-null   object
#  1   Account length          3332 non-null   int64
#  2   Area code               3332 non-null   int64
#  3   International plan      3332 non-null   object
#  4   Voice mail plan         3332 non-null   object
#  5   Number vmail messages   3332 non-null   int64
#  6   Total day minutes       3332 non-null   float64
#  7   Total day calls         3332 non-null   int64
#  8   Total day charge        3332 non-null   float64
#  9   Total eve minutes       3332 non-null   float64
#  10  Total eve calls         3332 non-null   int64
#  11  Total eve charge        3332 non-null   float64
#  12  Total night minutes     3332 non-null   float64
#  13  Total night calls       3332 non-null   int64
# ...

# %%
df["Churn"]=df["Churn"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3332 entries, 0 to 3331
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3332 non-null   object
#  1   Account length          3332 non-null   int64
#  2   Area code               3332 non-null   int64
#  3   International plan      3332 non-null   object
#  4   Voice mail plan         3332 non-null   object
#  5   Number vmail messages   3332 non-null   int64
#  6   Total day minutes       3332 non-null   float64
#  7   Total day calls         3332 non-null   int64
#  8   Total day charge        3332 non-null   float64
#  9   Total eve minutes       3332 non-null   float64
#  10  Total eve calls         3332 non-null   int64
#  11  Total eve charge        3332 non-null   float64
#  12  Total night minutes     3332 non-null   float64
#  13  Total night calls       3332 non-null   int64
# ...

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 0    2849
# 1     483
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# 0    0.855042
# 1    0.144958
# Name: proportion, dtype: float64

# %%
df.sort_values(by=["Churn","Total day charge"], ascending=[True,False])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 687     MN              13        510                 No             Yes
# 2258    NC             210        415                 No             Yes
# 533     LA              67        510                 No              No
# 574     SD             114        415                 No             Yes
# 2857    AL             141        510                 No             Yes
# ...    ...             ...        ...                ...             ...
# 1836    NH             117        510                Yes              No
# 2172    KS              47        510                Yes              No
# 2157    FL             166        510                Yes              No
# 1530    DE             138        510                Yes              No
# 1344    SD              98        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
churned_users=df[df["Churn"]==1]
numerica_features=churned_users.select_dtypes("number")
avg_val=numerica_features.mean()
avg_val
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
churned_users=df[df["Churn"]==1]
avg_spend=churned_users["Total day minutes"].mean()
print(avg_spend)
# Out:
# 206.91407867494823

# %%
data=df[(df["Churn"]==0) & (df["International plan"]=="No")]
max_len=data["Total intl calls"].max()
print(max_len)
# Out:
# 19

# %%
df.head(1)
df.tail(1)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3331    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3331                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3331             39.85              265.9               82              22.6
#
#       Total night minutes  Total night calls  Total night charge  \
# 3331                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3331                13.7                 4                3.7
#
#       Customer service calls  Churn
# 3331                       0      0

# %%
df["total_calls"]=df[["Total day calls","Total eve calls","Total night calls","Total intl calls"]].sum(axis=1)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       OH             107        415                 No             Yes
# 1       NJ             137        415                 No              No
# 2       OH              84        408                Yes              No
# 3       OK              75        415                Yes              No
# 4       AL             118        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3327    AZ             192        415                 No             Yes
# 3328    WV              68        415                 No              No
# 3329    RI              28        510                 No              No
# 3330    CT             184        510                Yes              No
# 3331    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
new=df.groupby("Area code")["Total day minutes"].mean()
new
# Out:
# Area code
# 408    177.175418
# 415    181.542140
# 510    178.787619
# Name: Total day minutes, dtype: float64

# %%
filtered_data=df[df['Customer service calls']<3]
median_data=filtered_data["Total night minutes"].median()
print(median_data)
# Out:
# 201.4

# %%
filtered_data=df[df['Voice mail plan']=="No"]
per_total=filtered_data['Total day calls'].quantile(0.75)
print(per_total)
# Out:
# 114.0

# %%
df["Area code"].nunique()
df["Area code"].value_counts()
# Out:
# Area code
# 415    1654
# 510     840
# 408     838
# Name: count, dtype: int64

# %%
data=df[df["Number vmail messages"]>10].groupby("State").size().div(df.groupby("State").size())*100
data
# Out:
# State
# AK    30.769231
# AL    26.250000
# AR    25.454545
# AZ    29.687500
# CA    32.352941
# CO    28.787879
# CT    28.378378
# DC    33.333333
# DE    22.950820
# FL    31.746032
# GA    35.185185
# HI    28.301887
# IA    27.272727
# ID    36.986301
# IL    25.862069
# IN    25.352113
# KS    26.086957
# KY    23.728814
# LA    25.490196
# MA    29.230769
# MD    24.285714
# ME    27.419355
# MI    28.767123
# MN    28.571429
# MO    26.984127
# MS    32.307692
# MT    35.294118
# NC    29.411765
# ND    33.870968
# NE    27.868852
# NH    28.571429
# NJ    29.411765
# NM    22.580645
# NV    21.212121
# NY    21.686747
# OH    33.333333
# OK    27.868852
# OR    21.794872
# PA    26.666667
# RI    27.692308
# SC    28.333333
# SD    35.000000
# TN    26.415094
# TX    22.222222
# UT    27.777778
# VA    23.376623
# VT    21.917808
# WA    15.151515
# WI    29.487179
# WV    27.358491
# WY    22.077922
# dtype: float64

# %%
data=df.groupby("State")["Total intl charge"].max()
data

print(data.idxmax(), data.max())
# Out:
# ME 5.4
