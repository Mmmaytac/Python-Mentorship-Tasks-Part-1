# %% [markdown]
# ## Task 1: Separating Even and Odd Numbers
#
# - Loop through the numbers from 1 to 50 using a for loop
# - If the number is even, add it to the even list
# - If the number is odd, add it to the odd list
# - At the end, print both lists

# %% [markdown]
# ## Task 2: Password Validation (while + if)
#
# - Ask the user to enter a password (using while)
# - The password must be at least 8 characters long
# - It must contain at least one digit
# - When the password is valid, print:
# Password accepted

# %% [markdown]
# ## Task 3
#
# - Get a sentence from the user
# - Split the sentence into words using split()
# - Find the number of words
# - Print the result like this:

# %%
# output: 
# Sentence: Hello world from Python
# Words: ['Hello', 'world', 'from', 'Python']
# Word count: 4

# %% [markdown]
# ## Task 4
#
# - Write a function: fix_name(name)
# - name is a string
# - Remove extra spaces using .strip()
# - Capitalize the first letter
# - Return the result

# %%
# Input: " aytac "
# Output: "Aytac"

# %% [markdown]
# ## Task 5
#
# Write a function:
#
# - Print all names and scores using a loop
# - Collect the students who scored above 90 into a separate list
# - Return that list

# %%
#The following dictionary is given:
scores = {
    "Ali": 85,
    "Aysel": 92,
    "Nigar": 78
}
# output: High scorers: ['Aysel']

# %% [markdown]
# ## Task 6
#
# Write a function: student_report(data)
#
# The function should:
#
# - Clean the names using strip() and format them correctly
# - Find the number of skills
# - Print the result like this:

# %%
#data is a dictionary:
students = {
    "  aySEL ": ["Python", "Java", "SQL"],
    " ali ": ["C++", "Python"]
}
# output: 
# Name: Aysel
# Skills: Python, Java, SQL
# Total skills: 3
# ----------------
# Name: Ali
# Skills: C++, Python
# Total skills: 2

# %% [markdown]
# ## Task 7
#
# - Get a sentence from the user
# - Split the sentence into words
# - Store the length of each word in a dictionary
# - Find the longest word
# - Print the result

# %%
# output:
# Sentence: Learning Python is amazing
# Word lengths: {'Learning': 8, 'Python': 6, 'is': 2, 'amazing': 7}
# Longest word: Learning

# %% [markdown]
# ## Task 7
# Write a function to complete the following task:
# - The function should take two arguments: text (a string) and n (a number)
# - Convert text into a list using list()
# - Create a new list where each element is repeated n times
# (e.g., 'a' and n = 3 → 'aaa')
# - Join the new list using ' - ' and return the result
# -Define the function with a default value of n = 3

# %%
# Examples:
# Input: process_text("Python", 2)
# Output: "PP - yy - tt - hh - oo - nn"

# %% [markdown]
# ## Task 8
# Requirements:
#
# - Write a function process_employees(data)
# - Create a dictionary where the key is a tuple (first_name, last_name) and the value contains age, position, and salary
# - Iterate over the dictionary using .items()
# - Print the names and salaries of employees who earn more than 4000 in a formatted way
# - Calculate the average age of all employees

# %%
#Process the following data structure:
employees = [
    ("John", "Doe", 28, "Developer", 3500),
    ("Jane", "Smith", 32, "Analyst", 4200),
    ("Bob", "Johnson", 45, "Manager", 5500),
    ("Alice", "Brown", 29, "Developer", 3700)
]
# Sample output:

# High Salary Employees:
# Jane Smith: 4200
# Bob Johnson: 5500

# Average Age: 33.5
# Out:
# High Salary Employees (>4000):
#   Jane Smith: 4200
#   Bob Johnson: 5500
#
# Average Age: 33.5
# Number of Developers: 2

# %% [markdown]
# ## Task 9
# Clean the unnecessary characters in the "Name" column of the following DataFrame using .strip()
# and replace "Baki" with "Bakı" in the "City" column.

# %%
import pandas as pd

data = {
    'Name': ['  Ali  ', 'Vəfa!', '  Leyla\n'],
    'City': ['Baki', 'Gəncə', 'Baki']
}

df =
